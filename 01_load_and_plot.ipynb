# %% [markdown]
# # Make sphere and plot it

# %%
import pyvista as pv

# %%
sphere = pv.Sphere()

# %%
sphere.plot()
# Out:
# /home/webtk/.pyenv/versions/3.10.15/lib/python3.10/site-packages/pyvista/jupyter/notebook.py:37: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
